# %% [markdown]
# ## Lab 2: Seaborn (From Matplolib and pandas to seaborn)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Laboratorio 2
# * Hacer el analisis estadístico de las variables: Millas por galón (mpg) vs potencia (horsepower) in the dataset: millas_por_galon.csv. Contruya el fit de al $95$ C.L.

# %%
#Importamos los datos 
ruta = r'C:\Users\jjrd2\OneDrive\Desktop\Fisica_Computacional_1\Sesiones\seaborn\millas_por_galon.csv'
df = pd.read_csv (ruta)

df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
#Analisis estadistico
Datos= df[['mpg','horsepower']].describe()
print(Datos)
# Out:
#               mpg  horsepower
# count  398.000000  392.000000
# mean    23.514573  104.469388
# std      7.815984   38.491160
# min      9.000000   46.000000
# 25%     17.500000   75.000000
# 50%     23.000000   93.500000
# 75%     29.000000  126.000000
# max     46.600000  230.000000

# %%
#Graficas
sns.set_theme()

sns.relplot(
    data=df,
    x='mpg',y='horsepower', 
    height=6,aspect= 2,   
)
plt.title('Comparativa caballos de fuerza VS millas por galon.')

sns.relplot(
    data=df,
    x='mpg',y='horsepower',
    hue='origin',
    col='origin',
    aspect=2, height=3   
)

plt.show()

# %%
# Regresión polinomial con intervalo de confianza
sns.regplot(
    data=df,
    x='mpg',y='horsepower',
    order=4,  # Grado del polinomio 
    ci=95,
    scatter_kws={'color':'grey'},
    line_kws={'color':'red'},
)

plt.title('Relación MPG vs. Horsepower (Ajuste Polinomial + 95% C.L.)')
plt.show()

# %% [markdown]
# COLOCAR LA ECUACION POLINOMICA...

# %% [markdown]
# 2. Descargar el dataframe : https://github.com/anferivera/SDdiracDM/blob/master/general-scan.csv
#   desde GitHUb y reconstruir la figura 6 del [trabajo](https://journals.aps.org/prd/abstract/10.1103/PhysRevD.100.035029). Para ello usar `seaborn` y `matplolib`.
#
#
#   * $M_N=h_s\dfrac{v_s}{\sqrt{2}}$
#   * $v_s =$ vS
#   * $h_s=$ YRC
#   * $M_\Psi=$ MDF
#   * $M_{\chi_1^0}=$ mChi1
#   * $\Omega_{\chi_1^0}=$ Omega
#   * $\Omega_{DM}=0.12$

# %%
url = 'https://raw.githubusercontent.com/anferivera/SDdiracDM/master/general-scan.csv'
datos_2 = pd.read_csv(url)
datos_2
# Out:
#        Unnamed: 0          MDF          MS12          MS22    LamS1H  \
# 0               0   396.848661  2.137304e+06  2.137304e+06  0.020984
# 1               1  5988.499243  1.889315e+07  1.889315e+07  0.023341
# 2               2   452.875632  2.469280e+06  2.469280e+06  0.000490
# 3               3   589.443344  9.826674e+07  9.826674e+07  0.042790
# 4               4  1092.250036  2.054042e+06  2.054042e+06  0.002196
# ...           ...          ...           ...           ...       ...
# 17391          19  1117.302129  2.175653e+06  2.175653e+06  0.008842
# 17392          20  1134.026597  2.092129e+06  2.092129e+06  0.090092
# 17393          21  1135.029100  2.819239e+07  2.819239e+07  0.008246
# 17394          22  4256.415506  1.462197e+06  1.462197e+06  0.014256
# 17395          23  1133.004091  1.151335e+08  1.151335e+08  0.001240
#
#          LamS2H    LamSPH      LamS     LamSP            vS  ...         U  \
# 0      0.020984  0.020052  0.000000  0.217236    702.109163  ...  0.001075
# 1      0.023341  0.000181  0.000000  0.019173    329.668504  ... -0.002513
# 2      0.000490  0.017861  0.000000  0.337367   3843.138599  ...  0.000638
# 3      0.042790  0.031174  0.000000  0.270921    314.258778  ...  0.000181
# 4      0.002196  0.002346  0.000000  0.046671  13048.623894  ...  0.000066
# ...         ...       ...       ...       ...           ...  ...       ...
# 17391  0.008842  0.000272  0.201033  0.001103  27580.576196  ...  0.000063
# 17392  0.090092  0.000389  0.001842  0.463102   5738.478616  ...  0.000061
# 17393  0.008246  0.001548  0.038374  1.342324  44788.888482  ...  0.000061
# 17394  0.014256  0.001920  0.002212  0.159277    428.133858  ...  0.000004
# 17395  0.001240  0.001669  0.000153  0.087216   1922.699240  ...  0.000061
#
#        mueg        taumug            sv      ZH11      ZH12      ZH21  \
# 0       0.0  1.773785e-19  1.860000e-26  0.999293 -0.037599  0.037599
# 1       0.0  1.791040e-18  2.580000e-31  0.001084 -0.999999 -0.999999
# 2       0.0  4.833919e-18  1.220000e-26  0.999994 -0.003384  0.003384
# 3       0.0  9.406560e-16  2.740000e-30  0.979480 -0.201541  0.201541
# 4       0.0  1.002187e-13  1.970000e-26  1.000000 -0.000945  0.000945
# ...     ...           ...           ...       ...       ...       ...
# 17391   0.0  3.277485e-15  1.930000e-26  0.999998 -0.002229  0.002229
# 17392   0.0  2.432178e-13  1.940000e-26  1.000000 -0.000036  0.000036
# 17393   0.0  2.842254e-18  1.890000e-26  1.000000 -0.000006  0.000006
# 17394   0.0  3.530488e-26  2.220000e-30  0.999891 -0.014794  0.014794
# 17395   0.0  9.262506e-24  1.920000e-26  0.999997 -0.002560  0.002560
#
#            ZH22    BRh1gg    BRh2gg
# 0      0.999293  0.002837  0.000000
# 1     -0.001084  0.000342  0.002816
# 2      0.999994  0.002822  0.000000
# 3      0.979480  0.002838  0.000194
# 4      1.000000  0.002827  0.000000
# ...         ...       ...       ...
# 17391  0.999998  0.002827  0.000000
# 17392  1.000000  0.002827  0.000000
# 17393  1.000000  0.002827  0.000000
# 17394  0.999891  0.002819  0.000140
# 17395  0.999997  0.002827  0.000000
#
# [17396 rows x 60 columns]

# %%
#Creamos un vector con los datos para graficar
m_n = datos_2['YRC'] * datos_2['vS']/ np.sqrt(2)

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(100, 10000)  
ax.set_ylim(5, 10000) 

plt.scatter(x=datos_2['MDF'],y=m_n)
plt.show()

# %%
datos_2.columns
# Out:
# Index(['Unnamed: 0', 'MDF', 'MS12', 'MS22', 'LamS1H', 'LamS2H', 'LamSPH',
#        'LamS', 'LamSP', 'vS', 'YRD', 'YRC', 'YRA11', 'YRA12', 'YRA13', 'YRA21',
#        'YRA22', 'YRA23', 'YRB11', 'YRB12', 'YRB13', 'YRB21', 'YRB22', 'YRB23',
#        'mh1', 'mh2', 'mv3', 'mv2', 'mv1', 'mS1', 'mS2', 'mCha', 'mChi1',
#        'mChi2', 'XV11', 'XV12', 'XV21', 'XV22', 'XU11', 'XU12', 'XU21', 'XU22',
#        'vevSM', 'Omega', 'PSI', 'PSD', 'NSI', 'NSD', 'T', 'S', 'U', 'mueg',
#        'taumug', 'sv', 'ZH11', 'ZH12', 'ZH21', 'ZH22', 'BRh1gg', 'BRh2gg'],
#       dtype='str')

# %%
datos_2['M_N'] = datos_2['YRC'] * (datos_2['vS'] / np.sqrt(2))
datos_2['M_Psi'] = datos_2['MDF']

Omega_DM = 0.12
tol = 0.01 
df_correctos = datos_2[
    (datos_2['Omega'] >= Omega_DM - tol) & (datos_2['Omega'] <= Omega_DM + tol)
]

# 3. Configuración de las graficas
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(100, 10000)
ax.set_ylim(8, 10000)


x_red_left = np.array([100, 1000])
y_red_left = np.array([100, 1000])
ax.fill_between(
    x_red_left, y_red_left, 10000, color='#fa8072', alpha=0.9, zorder=1
)

x_red_right = np.array([1300, 3000, 5000, 8000, 10000])
y_red_right = np.array([1500, 2000, 1800, 1500, 1200])
ax.fill_between(
    x_red_right, y_red_right, 10000, color='#fa8072', alpha=0.9, zorder=1
)
ax.fill_between(
    [1000, 10000], [10000, 10000], [10000, 10000], color='#fa8072', zorder=1
)


ax.axhspan(
    8, 60, color='#4ba359', zorder=1
)
ax.axvspan(
    900, 1300, ymin=0.55, ymax=1.0, color='#4ba359', zorder=1
)  

ax.scatter(
    df_correctos['M_Psi'],
    df_correctos['M_N'],
    color='blue',
    s=6,
    alpha=0.8,
    label=r'$\Omega h^2 - m_{\nu_\alpha}$',
    zorder=3,
)

ax.text(
    150, 900, r'$\mathbf{\Omega_{\chi_1^0} < \Omega_{DM}}$', fontsize=13
)
ax.text(
    2200, 2500, r'$\mathbf{\Omega_{\chi_1^0} > \Omega_{DM}}$', fontsize=13
)


ax.set_xlabel(r'$M_{\Psi}\ \mathbf{(GeV)}$', fontsize=12)
ax.set_ylabel(r'$M_N\ \mathbf{(GeV)}$', fontsize=12)

blue_dots = plt.Line2D(
    [0],
    [0],
    marker='o',
    color='w',
    markerfacecolor='blue',
    markersize=5,
    label=r'$\Omega h^2 - m_{\nu_\alpha}$',
)

ax.legend(
    loc='lower right',
    frameon=True,
    facecolor='#eAF4eA',
    edgecolor='gray',
    fontsize=10,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# NOTA 2.3+2.2 NO USA RELAMENTE LOS FILTROS DE PANDAS... SOLO EL FILBETWEEN...
